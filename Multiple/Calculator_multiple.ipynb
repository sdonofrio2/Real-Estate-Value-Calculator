# %%
 # Import libraries
import pandas as pd
import pickle as pk

# import libraries for api
import os
from dotenv import load_dotenv 
import requests
import json

# import libraries for vizualization
import seaborn as sns
import holoviews as hv
import hvplot.pandas
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
import panel as pn
from pprint import pprint

# %%
### Open data from a pickle : Zillow_data, which represent the houses currently for sale
filename = "Zillow_data"
infile = open(filename,'rb')
new_dict = pk.load(infile)
infile.close()

### transform to json
z_for_sale_resp =new_dict.json()

### transform json to datafram
current_zillow_df = pd.json_normalize(data=z_for_sale_resp["props"])
print('num of rows:', len(current_zillow_df))
print('num of columns:', len(current_zillow_df.columns))

current_zillow_df.head()
# Out:
# num of rows: 40
# num of columns: 21
#    bathrooms   propertyType  lotAreaValue  \
# 0        3.0  SINGLE_FAMILY   7405.000000
# 1        4.0  SINGLE_FAMILY      0.430005
# 2        2.0  SINGLE_FAMILY   5663.000000
# 3        1.0  SINGLE_FAMILY   3049.000000
# 4        2.0  SINGLE_FAMILY   2178.000000
#
#                                      address  \
# 0  6326 Hasbrook Ave, Philadelphia, PA 19111
# 1    200 W Walnut Ln, Philadelphia, PA 19144
# 2      2843 Comly Rd, Philadelphia, PA 19154
# 3      819 Levick St, Philadelphia, PA 19111
# 4  6132 Christian St, Philadelphia, PA 19143
#
#                                               imgSrc   price  listingDateTime  \
# 0  https://photos.zillowstatic.com/fp/5cec86dede3...  305000    1636502400000
# 1  https://photos.zillowstatic.com/fp/b90b6b03745...  869000    1631577600000
# 2  https://photos.zillowstatic.com/fp/52664dfa32d...  279900    1636934400000
# 3  https://photos.zillowstatic.com/fp/c7277135d77...  210000    1636934400000
# 4  https://photos.zillowstatic.com/fp/46abfc40564...  289900    1636934400000
#
#    longitude listingStatus        zpid  ...  lotAreaUnit daysOnZillow  \
# 0 -75.100046      FOR_SALE    10360239  ...         sqft            7
# 1 -75.181814      FOR_SALE  2068504637  ...        acres           64
# 2 -74.997753      FOR_SALE    10584074  ...         sqft            2
# 3 -75.089118      FOR_SALE    10359239  ...         sqft            2
# 4 -75.246715      FOR_SALE    10186985  ...         sqft            2
#
#    bedrooms  country currency livingArea  hasImage  listingSubType.is_FSBA  \
# 0         5      USA      USD       2100      True                    True
# 1         5      USA      USD       3857      True                    True
# 2         3      USA      USD       1584      True                    True
# 3         3      USA      USD       1200      True                    True
# 4         4      USA      USD       1840      True                    True
#
#   listingSubType.is_openHouse listingSubType.is_bankOwned
# 0                        True                         NaN
# 1                         NaN                         NaN
# 2                        True                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
#
# [5 rows x 21 columns]

# %%
### Data cleaning from dataset Zillow_data --------------------------------------------------------------------------------------------------------------
# Select columns that we will need for the analysis
current_price_df = current_zillow_df[[ "zpid","propertyType" , "price", "livingArea" , "bathrooms" , "bedrooms" ,"address", "listingStatus" , "latitude" , "longitude", "imgSrc"]].copy()
current_price_df.set_index("zpid", inplace=True)

#Pull only the zip code from the address column
current_price_df["address"] = current_price_df["address"].str[-5:]

# Change the column names to improve readability
current_price_df.rename(columns = {
        "livingArea" : "Area in sqft.",
        "propertyType" : "Type of Property",
        "address" : "zip code",
        "listingStatus" : "Status",
        "imgSrc" : "Image property"
        }, inplace = True)

#Add new columns in dataframes for "price per sqft"
current_price_df["price_per_sqft"] = current_price_df["price"] / current_price_df["Area in sqft."]

current_price_df.head()
# Out:
#            Type of Property   price  Area in sqft.  bathrooms  bedrooms  \
# zpid
# 10360239      SINGLE_FAMILY  305000           2100        3.0         5
# 2068504637    SINGLE_FAMILY  869000           3857        4.0         5
# 10584074      SINGLE_FAMILY  279900           1584        2.0         3
# 10359239      SINGLE_FAMILY  210000           1200        1.0         3
# 10186985      SINGLE_FAMILY  289900           1840        2.0         4
#
#            zip code    Status   latitude  longitude  \
# zpid
# 10360239      19111  FOR_SALE  40.051195 -75.100046
# 2068504637    19144  FOR_SALE  40.037048 -75.181814
# 10584074      19154  FOR_SALE  40.101684 -74.997753
# 10359239      19111  FOR_SALE  40.046245 -75.089118
# 10186985      19143  FOR_SALE  39.949598 -75.246715
#
#                                                Image property  price_per_sqft
# zpid
# 10360239    https://photos.zillowstatic.com/fp/5cec86dede3...      145.238095
# 2068504637  https://photos.zillowstatic.com/fp/b90b6b03745...      225.304641
# 10584074    https://photos.zillowstatic.com/fp/52664dfa32d...      176.704545
# 10359239    https://photos.zillowstatic.com/fp/c7277135d77...      175.000000
# 10186985    https://photos.zillowstatic.com/fp/46abfc40564...      157.554348

# %%
### Open data from a pickle : Zillow_old_data, which represent the houses recently sold and similar to the current one for sale
filename = "Zillow_sold_data"
infile = open(filename,'rb')
zpid_dict = pk.load(infile)
infile.close()

# Data extracted from Zillow_old_data, is in json() format, the for loop aims to transfort each key of this data in a DataFrame and add it to a general one called: sold_zillow_df .
sold_zillow_df= pd.DataFrame()

for key in zpid_dict:
    
    df_similar= pd.json_normalize(data= zpid_dict[key])
    df_similar["origine ZPID"] = key
    sold_zillow_df = pd.concat( [sold_zillow_df, df_similar], axis=0, join = "outer")
    

# Reset index from sold_zillow_df
sold_zillow_df.reset_index(inplace=True) 

# Print some information about the combined dataframe
print('num of rows:', len(sold_zillow_df))
print('num of columns:', len(sold_zillow_df.columns))
sold_zillow_df.head(10)
# Out:
# num of rows: 68
# num of columns: 21
#    index      dateSold  bedrooms     homeStatus   latitude  \
# 0      0  1.626826e+12       4.0        PENDING  40.052106
# 1      1  1.607990e+12       5.0  RECENTLY_SOLD  40.052383
# 2      2  1.631837e+12       3.0  RECENTLY_SOLD  40.050943
# 3      3  1.628122e+12       4.0  RECENTLY_SOLD  40.052527
# 4      4  1.599005e+12       5.0           SOLD  40.053611
# 5      5  1.626307e+12       5.0  RECENTLY_SOLD  40.053664
# 6      6  1.625011e+12       6.0  RECENTLY_SOLD  40.051388
# 7      7  1.580429e+12       3.0           SOLD  40.050343
# 8      8  1.604621e+12       4.0           SOLD  40.053402
# 9      9  1.604621e+12       4.0           SOLD  40.057228
#
#                                       miniCardPhotos          zpid  longitude  \
# 0  [{'url': 'https://photos.zillowstatic.com/fp/e...  1.036019e+07 -75.101203
# 1  [{'url': 'https://photos.zillowstatic.com/fp/c...  2.077604e+09 -75.098753
# 2  [{'url': 'https://photos.zillowstatic.com/fp/f...  1.035894e+07 -75.101819
# 3  [{'url': 'https://photos.zillowstatic.com/fp/e...  1.035938e+07 -75.096352
# 4  [{'url': 'https://photos.zillowstatic.com/fp/e...  1.035975e+07 -75.093131
# 5  [{'url': 'https://photos.zillowstatic.com/fp/8...  2.073107e+09 -75.094718
# 6  [{'url': 'https://photos.zillowstatic.com/fp/2...  1.036039e+07 -75.097422
# 7  [{'url': 'https://maps.googleapis.com/maps/api...  8.094959e+07 -75.098404
# 8  [{'url': 'https://photos.zillowstatic.com/fp/a...  1.035966e+07 -75.094256
# 9  [{'url': 'https://photos.zillowstatic.com/fp/2...  9.909662e+06 -75.099425
#
#    bathrooms  livingArea  ...       homeType currency lastSoldPrice     price  \
# 0        4.0      2216.0  ...  SINGLE_FAMILY      USD      325000.0  399999.0
# 1        3.0      1950.0  ...  SINGLE_FAMILY      USD      310000.0  310000.0
# 2        3.0      1600.0  ...  SINGLE_FAMILY      USD      280000.0  280000.0
# 3        3.0      2250.0  ...  SINGLE_FAMILY      USD      404000.0  404000.0
# 4        3.0      2188.0  ...  SINGLE_FAMILY      USD      207000.0  207000.0
# 5        4.0      2010.0  ...  SINGLE_FAMILY      USD      360000.0  360000.0
# 6        3.0      2848.0  ...  SINGLE_FAMILY      USD      480000.0  480000.0
# 7        2.0      1707.0  ...  SINGLE_FAMILY      USD      125000.0  125000.0
# 8        3.0      2100.0  ...  SINGLE_FAMILY      USD      390000.0  390000.0
# 9        3.0      1855.0  ...  SINGLE_FAMILY      USD      271000.0  271000.0
#
#    address.city address.state address.streetAddress address.zipcode  \
# 0  Philadelphia            PA      6328 Newtown Ave           19111
# 1  Philadelphia            PA  6430 Hasbrook Ave #A           19111
# 2  Philadelphia            PA        222 Robbins St           19111
# 3  Philadelphia            PA      335 Hellerman St           19111
# 4  Philadelphia            PA         420 Unruh Ave           19111
# 5  Philadelphia            PA       342 Fanshawe St           19111
# 6  Philadelphia            PA    6417 Shelbourne St           19111
# 7  Philadelphia            PA    6323 Shelbourne St           19111
# 8  Philadelphia            PA       400 Fanshawe St           19111
# 9    Cheltenham            PA          236 Boyer Rd           19012
#
#   origine ZPID message
# 0     10360239     NaN
# 1     10360239     NaN
# 2     10360239     NaN
# 3     10360239     NaN
# 4     10360239     NaN
# 5     10360239     NaN
# 6     10360239     NaN
# 7     10360239     NaN
# 8     10360239     NaN
# 9     10360239     NaN
#
# [10 rows x 21 columns]

# %%
### Data cleaning from dataset Zillow_data -----------------------------------------------------------------------------------------------------------------------
# Select columns that we will need for the analysis
sold_price_df = sold_zillow_df[[ "zpid", "homeType", "lastSoldPrice", "livingArea" , "bathrooms" , "bedrooms" , "address.zipcode",  "homeStatus" , "latitude" , "longitude", "miniCardPhotos"]].copy()
sold_price_df.set_index("zpid", inplace=True)



# Change the column names to improve readability
sold_price_df.rename(columns = {
        "homeType" : "Type of Property",
        "lastSoldPrice" : "price",
        "livingArea" : "Area in sqft.",
        "address.zipcode" :"zip code",
        "homeStatus" : "Status",
        "miniCardPhotos" : "Image property"
        }, inplace = True)

#Add new columns in dataframes for "price per sqft"
sold_price_df["price_per_sqft"] = sold_price_df["price"] / sold_price_df["Area in sqft."]

sold_price_df.head(40)
# Out:
#              Type of Property      price  Area in sqft.  bathrooms  bedrooms  \
# zpid
# 1.036019e+07    SINGLE_FAMILY   325000.0         2216.0        4.0       4.0
# 2.077604e+09    SINGLE_FAMILY   310000.0         1950.0        3.0       5.0
# 1.035894e+07    SINGLE_FAMILY   280000.0         1600.0        3.0       3.0
# 1.035938e+07    SINGLE_FAMILY   404000.0         2250.0        3.0       4.0
# 1.035975e+07    SINGLE_FAMILY   207000.0         2188.0        3.0       5.0
# 2.073107e+09    SINGLE_FAMILY   360000.0         2010.0        4.0       5.0
# 1.036039e+07    SINGLE_FAMILY   480000.0         2848.0        3.0       6.0
# 8.094959e+07    SINGLE_FAMILY   125000.0         1707.0        2.0       3.0
# 1.035966e+07    SINGLE_FAMILY   390000.0         2100.0        3.0       4.0
# 9.909662e+06    SINGLE_FAMILY   271000.0         1855.0        3.0       4.0
# 1.035925e+07    SINGLE_FAMILY   225000.0         1188.0        2.0       3.0
# 1.035944e+07    SINGLE_FAMILY   200000.0         2016.0        3.0       5.0
# 1.035948e+07    SINGLE_FAMILY   329000.0         2400.0        2.0       5.0
# 1.035949e+07    SINGLE_FAMILY   265000.0         3400.0        3.0       6.0
# 9.909069e+06    SINGLE_FAMILY   278000.0         2159.0        3.0       4.0
# 1.035938e+07    SINGLE_FAMILY   147805.0         1645.0        2.0       4.0
# 1.035944e+07    SINGLE_FAMILY   201000.0         2183.0        2.0       4.0
# 8.094840e+07    SINGLE_FAMILY   175000.0         2250.0        3.0       3.0
# 1.036032e+07    SINGLE_FAMILY   260000.0         1628.0        2.0       4.0
# 1.035792e+07    SINGLE_FAMILY   210000.0         2475.0        3.0       5.0
# 9.916432e+06    SINGLE_FAMILY   294000.0         2567.0        3.0       4.0
# 1.035936e+07    SINGLE_FAMILY   285000.0         1904.0        2.0       5.0
# 9.909683e+06    SINGLE_FAMILY   287000.0         2010.0        3.0       4.0
# 1.036068e+07    SINGLE_FAMILY   259900.0         1890.0        2.0       3.0
# 1.035975e+07    SINGLE_FAMILY   402500.0         3125.0        3.0       6.0
# 1.183360e+08    SINGLE_FAMILY   850000.0         2875.0        0.0       NaN
# 1.053923e+07    SINGLE_FAMILY   815000.0         6963.0        5.0       7.0
# 1.053928e+07    SINGLE_FAMILY   720000.0         3592.0        3.0       6.0
# 2.144925e+09    SINGLE_FAMILY   650000.0            NaN        NaN       NaN
# 8.094334e+07    SINGLE_FAMILY  1000000.0         5976.0        NaN       NaN
# NaN                       NaN        NaN            NaN        NaN       NaN
# NaN                       NaN        NaN            NaN        NaN       NaN
# NaN                       NaN        NaN            NaN        NaN       NaN
# NaN                       NaN        NaN            NaN        NaN       NaN
# NaN                       NaN        NaN            NaN        NaN       NaN
# NaN                       NaN        NaN            NaN        NaN       NaN
# NaN                       NaN        NaN            NaN        NaN       NaN
# NaN                       NaN        NaN            NaN        NaN       NaN
# NaN                       NaN        NaN            NaN        NaN       NaN
# NaN                       NaN        NaN            NaN        NaN       NaN
#
#              zip code         Status   latitude  longitude  \
# zpid
# 1.036019e+07    19111        PENDING  40.052106 -75.101203
# 2.077604e+09    19111  RECENTLY_SOLD  40.052383 -75.098753
# 1.035894e+07    19111  RECENTLY_SOLD  40.050943 -75.101819
# 1.035938e+07    19111  RECENTLY_SOLD  40.052527 -75.096352
# 1.035975e+07    19111           SOLD  40.053611 -75.093131
# 2.073107e+09    19111  RECENTLY_SOLD  40.053664 -75.094718
# 1.036039e+07    19111  RECENTLY_SOLD  40.051388 -75.097422
# 8.094959e+07    19111           SOLD  40.050343 -75.098404
# 1.035966e+07    19111           SOLD  40.053402 -75.094256
# 9.909662e+06    19012           SOLD  40.057228 -75.099425
# 1.035925e+07    19111  RECENTLY_SOLD  40.053095 -75.099592
# 1.035944e+07    19111  RECENTLY_SOLD  40.052202 -75.095166
# 1.035948e+07    19111  RECENTLY_SOLD  40.053008 -75.095706
# 1.035949e+07    19111  RECENTLY_SOLD  40.052597 -75.094961
# 9.909069e+06    19012           SOLD  40.057460 -75.102860
# 1.035938e+07    19111           SOLD  40.052316 -75.095983
# 1.035944e+07    19111  RECENTLY_SOLD  40.052022 -75.094843
# 8.094840e+07    19111           SOLD  40.049679 -75.097110
# 1.036032e+07    19111  RECENTLY_SOLD  40.051727 -75.098002
# 1.035792e+07    19120           SOLD  40.045139 -75.107131
# 9.916432e+06    19012           SOLD  40.057061 -75.101076
# 1.035936e+07    19111  RECENTLY_SOLD  40.049998 -75.092871
# 9.909683e+06    19012           SOLD  40.058894 -75.102882
# 1.036068e+07    19111           SOLD  40.048262 -75.094923
# 1.035975e+07    19111  RECENTLY_SOLD  40.053783 -75.093440
# 1.183360e+08    19144  RECENTLY_SOLD  40.040894 -75.178550
# 1.053923e+07    19144  RECENTLY_SOLD  40.036705 -75.185010
# 1.053928e+07    19144  RECENTLY_SOLD  40.040060 -75.183650
# 2.144925e+09    19144  RECENTLY_SOLD  40.033016 -75.178185
# 8.094334e+07    19144  RECENTLY_SOLD  40.029877 -75.180300
# NaN               NaN            NaN        NaN        NaN
# NaN               NaN            NaN        NaN        NaN
# NaN               NaN            NaN        NaN        NaN
# NaN               NaN            NaN        NaN        NaN
# NaN               NaN            NaN        NaN        NaN
# NaN               NaN            NaN        NaN        NaN
# NaN               NaN            NaN        NaN        NaN
# NaN               NaN            NaN        NaN        NaN
# NaN               NaN            NaN        NaN        NaN
# NaN               NaN            NaN        NaN        NaN
#
#                                                  Image property  \
# zpid
# 1.036019e+07  [{'url': 'https://photos.zillowstatic.com/fp/e...
# 2.077604e+09  [{'url': 'https://photos.zillowstatic.com/fp/c...
# 1.035894e+07  [{'url': 'https://photos.zillowstatic.com/fp/f...
# 1.035938e+07  [{'url': 'https://photos.zillowstatic.com/fp/e...
# 1.035975e+07  [{'url': 'https://photos.zillowstatic.com/fp/e...
# 2.073107e+09  [{'url': 'https://photos.zillowstatic.com/fp/8...
# 1.036039e+07  [{'url': 'https://photos.zillowstatic.com/fp/2...
# 8.094959e+07  [{'url': 'https://maps.googleapis.com/maps/api...
# 1.035966e+07  [{'url': 'https://photos.zillowstatic.com/fp/a...
# 9.909662e+06  [{'url': 'https://photos.zillowstatic.com/fp/2...
# 1.035925e+07  [{'url': 'https://photos.zillowstatic.com/fp/4...
# 1.035944e+07  [{'url': 'https://photos.zillowstatic.com/fp/a...
# 1.035948e+07  [{'url': 'https://photos.zillowstatic.com/fp/e...
# 1.035949e+07  [{'url': 'https://photos.zillowstatic.com/fp/1...
# 9.909069e+06  [{'url': 'https://photos.zillowstatic.com/fp/a...
# 1.035938e+07  [{'url': 'https://maps.googleapis.com/maps/api...
# 1.035944e+07  [{'url': 'https://photos.zillowstatic.com/fp/6...
# 8.094840e+07  [{'url': 'https://maps.googleapis.com/maps/api...
# 1.036032e+07  [{'url': 'https://photos.zillowstatic.com/fp/2...
# 1.035792e+07  [{'url': 'https://maps.googleapis.com/maps/api...
# 9.916432e+06  [{'url': 'https://photos.zillowstatic.com/fp/b...
# 1.035936e+07  [{'url': 'https://photos.zillowstatic.com/fp/2...
# 9.909683e+06  [{'url': 'https://photos.zillowstatic.com/fp/8...
# 1.036068e+07  [{'url': 'https://maps.googleapis.com/maps/api...
# 1.035975e+07  [{'url': 'https://photos.zillowstatic.com/fp/5...
# 1.183360e+08  [{'url': 'https://photos.zillowstatic.com/fp/2...
# 1.053923e+07  [{'url': 'https://photos.zillowstatic.com/fp/0...
# 1.053928e+07  [{'url': 'https://photos.zillowstatic.com/fp/1...
# 2.144925e+09  [{'url': 'https://maps.googleapis.com/maps/api...
# 8.094334e+07  [{'url': 'https://maps.googleapis.com/maps/api...
# NaN                                                         NaN
# NaN                                                         NaN
# NaN                                                         NaN
# NaN                                                         NaN
# NaN                                                         NaN
# NaN                                                         NaN
# NaN                                                         NaN
# NaN                                                         NaN
# NaN                                                         NaN
# NaN                                                         NaN
#
#               price_per_sqft
# zpid
# 1.036019e+07      146.660650
# 2.077604e+09      158.974359
# 1.035894e+07      175.000000
# 1.035938e+07      179.555556
# 1.035975e+07       94.606947
# 2.073107e+09      179.104478
# 1.036039e+07      168.539326
# 8.094959e+07       73.227885
# 1.035966e+07      185.714286
# 9.909662e+06      146.091644
# 1.035925e+07      189.393939
# 1.035944e+07       99.206349
# 1.035948e+07      137.083333
# 1.035949e+07       77.941176
# 9.909069e+06      128.763316
# 1.035938e+07       89.851064
# 1.035944e+07       92.075126
# 8.094840e+07       77.777778
# 1.036032e+07      159.705160
# 1.035792e+07       84.848485
# 9.916432e+06      114.530580
# 1.035936e+07      149.684874
# 9.909683e+06      142.786070
# 1.036068e+07      137.513228
# 1.035975e+07      128.800000
# 1.183360e+08      295.652174
# 1.053923e+07      117.047250
# 1.053928e+07      200.445434
# 2.144925e+09             NaN
# 8.094334e+07      167.336011
# NaN                      NaN
# NaN                      NaN
# NaN                      NaN
# NaN                      NaN
# NaN                      NaN
# NaN                      NaN
# NaN                      NaN
# NaN                      NaN
# NaN                      NaN
# NaN                      NaN
